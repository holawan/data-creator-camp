# %% [markdown]
# #  2021년 데이터 크리에이터 캠프 예선 (헬스케어)  10-30 예선 10회
#
# ![데이터캠프](https://i.imgur.com/fVakQcm.png)
#
# - 출제자: 이현승 (hslrock@korea.ac.kr)

# %% [markdown]
# ## 🔥🔥🔥🔥다음 코드는 한글 깨짐 방지를 위해 필수 실행 코드입니다🔥🔥🔥
#
# >이후 런타임 런타임 다시 시작 을 클릭하여 런타임을 재시작합니다. 재시작후 다음 코드로 넘어가주시면됩니다

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

#런타임 -런타임 다시시작
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# ## 📌 출제 배경
#
# > 헬스케어 (healthcare) 데이터는 최근 들어 많이 주목받고 있는 데이터입니다. 과거 의사들이 직접 진료를 진행했다면 AI 기반 로봇들은 환자의 측정기록을 통해 환자의 상태를 분류할 수 있습니다 (질병 종류, 환자 나이)
#
# > 본 과제에서 사용하는 데이터는 서울올림픽기념 국민체육진흥공단에서 관리하는 국민 체력측정데이터의 항목별 측정 정보 데이터입니다. 현재 국민 체력 관련 연구를 진행할 때 사용되기도 합니다. 본 데이터의 측정기록을 통해 연령대와 체력 등급을 분류해봅시다.
#
# ![국민체력](https://i.imgur.com/mQaXU0v.png)

# %% [markdown]
# ## 📌 데이터 설명

# %% [markdown]
# ### 서울올림픽기념 국민체육진흥공단에서 관리하고 있는 국민체력측정데이터의 항목별 측정 정보를 제공하는 데이터입니다.
# 캐글/데이터 링크: https://www.kaggle.com/t/f480b32d2b834986bb725ac491f78d9d
#
# 구글드라이브 링크: https://drive.google.com/file/d/1F8KdFRorwsuxlKl1jjbdcC5AE4nmAgYe/view?usp=sharing

# %% [markdown]
# ## 📌 피처(Feature) 상세 설명
#
#
#
# | 피쳐이름 | 설명  |
# |------------|---|
# |  TEST_SEX |                  측정회원성별                  |
# | ITEM_F001 |            측정항목값 : 신장   : cm            |
# | ITEM_F002 |            측정항목값 : 체중   : kg            |
# | ITEM_F003 |           측정항목값 :   체지방율 : %          |
# | ITEM_F004 |          측정항목값 :   허리둘레 : cm          |
# | ITEM_F005 |     측정항목값 :   이완기혈압(최저) : mmHg     |
# | ITEM_F006 |     측정항목값 :   수축기혈압(최고) : mmHg     |
# | ITEM_F007 |            측정항목값 : 악력D   : kg           |
# | ITEM_F008 |           측정항목값 :   악력ND : kg           |
# | ITEM_F009 |       측정항목값 :   윗몸말아올리기 : 회       |
# | ITEM_F010 |          측정항목값 :   반복점프 : 회          |
# | ITEM_F011 |                      미정                      |
# | ITEM_F012 |    측정항목값 :   앉아윗몸앞으로굽히기 : cm    |
# | ITEM_F013 |          측정항목값 :   일리노이 : 초          |
# | ITEM_F014 |          측정항목값 :   체공시간 : 초          |
# | ITEM_F015 |         측정항목값 :   협응력시간 : 초         |
# | ITEM_F016 |       측정항목값 :   협응력실수횟수 : 회       |
# | ITEM_F017 |      측정항목값 :   협응력계산결과값 : 초      |
# | ITEM_F018 |           측정항목값 : BMI   : kg/㎡           |
# | ITEM_F019 |      측정항목값 :   교차윗몸일으키기 : 회      |
# | ITEM_F020 |       측정항목값 :   왕복오래달리기 : 회       |
# | ITEM_F021 |     측정항목값 : 10M   4회 왕복달리기 : 초     |
# | ITEM_F022 |       측정항목값 : 제자리   멀리뛰기 : cm      |
# | ITEM_F023 |    측정항목값 :   의자에앉았다일어서기 : 회    |
# | ITEM_F024 |           측정항목값 :   6분걷기 : m           |
# | ITEM_F025 |        측정항목값 :   2분제자리걷기 : 회       |
# | ITEM_F026 | 측정항목값 :   의자에앉아 3M표적 돌아오기 : 초 |
# | ITEM_F027 |           측정항목값 :   8자보행 : 초          |
# | ITEM_F028 |           측정항목값 :   상대악력 : %          |
# | ITEM_F029 |            측정항목값 :   피두부겹합           |
# | ITEM_F030 |  측정항목값 :   왕복오래달리기(출력) : VO₂max  |
# | ITEM_F031 |      측정항목값 :   트레드밀_안정시 : bpm      |
# | ITEM_F032 |        측정항목값 :   트레드밀_3분 : bpm       |
# | ITEM_F033 |        측정항목값 :   트레드밀_6분 : bpm       |
# | ITEM_F034 |        측정항목값 :   트레드밀_9분 : bpm       |
# | ITEM_F035 |     측정항목값 :   트레드밀(출력) : VO₂max     |
# | ITEM_F036 |   측정항목값 :   스텝검사_회복시 심박수 : bpm  |
# | ITEM_F037 |     측정항목값 :   스텝검사(출력) : VO₂max     |
# | ITEM_F038 |            측정항목값 :   허벅지(좌)           |
# | ITEM_F039 |            측정항목값 :   허벅지(우)           |
# | ITEM_F040 |          측정항목값 :   전신반응 : 초          |
# | ITEM_F041 |          측정항목값 :   체공시간2 : 초         |

# %% [markdown]
#  ## 📌 평가방법
#
# - 이후 다른 실험자들의 데이터로 나이와 등급을 예측하는것이 목표입니다, kaggle 에서 제공하는 결과로 평가할것입니다
#
# ```
#
# 예측 하여야 되는 값
# 나이: [10,20,30,40,50대]
# 등급: [1등급,2등급,3등급,참가증]
#
# ```
#
# - classification_report 이란?
#
# ```
# sklearn.metrics.classification_report
# ```
# 에서 나오는 결과값으로 분류에서 나오는 precision/recall 그리고 F1 score를 제공합니다. [링크](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)

# %% [markdown]
# # 베이스라인 코드(BaseLine Code)

# %% [markdown]
# ##  🖥 라이브러리 불러오기(import)

# %%
import numpy as np  #형렬 처리에 필요한 라이브러리입니다
import pandas as pd #데이터 관리 툴
import seaborn as sns #시각적 툴
import matplotlib.pyplot as plt ##시각적 툴
from datetime import datetime

import warnings
warnings.filterwarnings("ignore")
import importlib


import sklearn
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

from glob import glob #디렉토리 검색
import os
plt.rc('font', family='NanumBarunGothic') 

# %matplotlib inline

# %% [markdown]
# ##  🖥 사용자 함수(user_defined functions)

# %%
def get_model(model_name):
    model_dict = {"LogisticRegression": "sklearn.linear_model",
                  "LogisticRegressionCV": "sklearn.linear_model",
                  "PassiveAggressiveClassifier": "sklearn.linear_model",
                  "Perceptron": "sklearn.linear_model",
                  "RidgeClassifier": "sklearn.linear_model",
                  "SGDClassifier": "sklearn.ensemble",
                  "AdaBoostClassifier": "sklearn.ensemble",
                  "BaggingClassifier": "sklearn.ensemble",
                  "ExtraTreesClassifier": "sklearn.ensemble",
                  "GradientBoostingClassifier": "sklearn.ensemble",
                  "RandomForestClassifier": "sklearn.ensemble"
                  }
    return model_dict[model_name] 

def plot_result(y_true, y_pred):
    print(classification_report(y_true, y_pred,digits=4))

# Preprocessing 
def get_preprocess(module_name):
    preprocess_dict = {
        # scaler
        "PCA": "sklearn.decomposition",
        "NMF": "sklearn.decomposition",
        # scaler
        "StandardScaler": "sklearn.preprocessing",
        "MinMaxScaler": "sklearn.preprocessing",
        "MaxAbsScaler": "sklearn.preprocessing",
        "RobustScaler": "sklearn.preprocessing",
    }
    return preprocess_dict[module_name]

def pprint(preprocess_list):
    print('='*40)
    print('[INFO] Details ...')
    for key,value in preprocess_list:
        print(f'{key:<10s}: {value:}')
    print('='*40)
    return None 


# Submmision 
def submmision(config,pred_y_1,pred_y_2,index):
    
    PATH = config.SYSTEM.SAVE_DIR
    TEAM_NAME = config.SYSTEM.TEAM_NAME.replace(" ","") # 공백제거
    
    # Make output directory
#     SAVE_PATH = os.path.join(PATH)
    os.makedirs(PATH, exist_ok=True)

    today = datetime.now().strftime("%Y%m%d_%H%M%S")
    csv_name = os.path.join(PATH, f'{TEAM_NAME}_{today}.csv')
    index+=1
    # 결과 파일 저장 
    submmision = pd.DataFrame(data=index,columns=['NAME'])
    submmision['AGE_GROUP'] = pred_y_1
    submmision['CERT_GBN'] = pred_y_2
    submmision.to_csv(csv_name,index=False)
    
    display(submmision)
    print(f'[INFO] DATE: {today}')
    print(f'[INFO] 제출 파일 저장 완료: {csv_name}')
    
# Config
class AttributeDict(dict):
    def __init__(self):
        self.__dict__ = self
class ConfigTree:
    def __init__(self):
        self.DATAPATH = AttributeDict()
        self.SYSTEM = AttributeDict()

        self.MODEL = AttributeDict()
        self.PREPROCESS = AttributeDict()
        
# Pipeline 
class HealthClass():
    def __init__(self, cfg, module_params=None):
        self.model_name = cfg.MODEL.NAME
        self.preprocess_dict = self.update_dict()
    
    def update_dict(self):
        preprocess_dict = {}
        try:
            if config.PREPROCESS.reduce_dim:
                preprocess_dict.update(config.PREPROCESS.reduce_dim)
        except:
            pass
        try:
            if config.PREPROCESS.SCALER:
                preprocess_dict.update(config.PREPROCESS.SCALER)
        except:
            pass
            
        return preprocess_dict
  
    def get_string(self, module_name: str, import_module: str, module_params=None):
        """Returns a scikit-learn module from string."""
        module_class = getattr(importlib.import_module(import_module), module_name)
        if module_params:  
            module = module_class(**module_params)
        else:
            module = module_class()
        return module
    
    def build_pipline(self, reduce_dim_params=None, scaler_params=None, model_params=None):
        preprocess_list = []
        pipe = None
        try:
            model = self.get_string(self.model_name, get_model(self.model_name), model_params)
            for key, value in self.preprocess_dict.items():
                if key =='reduce_dim' and value:
                    module = self.get_string(value, get_preprocess(value), reduce_dim_params)
                elif key == 'scaler' and value:
                    module = self.get_string(value, get_preprocess(value), scaler_params)
                preprocess_list.append((key, module))
                    
            preprocess_list.append(('model', model))

            pipe = Pipeline(preprocess_list)

            print(f'[INFO] PIPELINE SETUP SUCCESS')
            pprint(preprocess_list)
        except:
            print('해당 모델을 제공하지 않습니다.')
        return pipe

# %% [markdown]
# <hr style="height:3px;border:none;color:#5F71F7;background-color:#5F71F7;" />
#
# ## 🖥 EDA(Exploratory Data Analysis)

# %%
# TRAIN 데이터 불러오기
df = pd.read_csv(os.path.join('merged_train.csv'))
# TRAIN 데이터 형태 확인하기
print('전체 데이터 행:{}, 열:{}'.format(*df.shape))
display(df.head())
# Out:
# 전체 데이터 행:66388, 열:44
#   TEST_SEX  ITEM_F001  ITEM_F002  ...  ITEM_F041  AGE_GROUP  CERT_GBN
# 0        F      162.7       56.4  ...      0.539        40대       1등급
# 1        M      168.6       66.6  ...        NaN        50대       참가증
# 2        F      162.6       62.4  ...        NaN        10대       참가증
# 3        M      179.3       84.1  ...        NaN        30대       참가증
# 4        M      174.5       75.4  ...        NaN        50대       참가증
#
# [5 rows x 44 columns]

# %%
# TEST 데이터 불러오기
test_df = pd.read_csv(os.path.join('final_test.csv'))
# TEST 데이터 형태 확인하기
print('전체 데이터 행:{}, 열:{}'.format(*test_df.shape))
display(test_df.head())
# Out:
# 전체 데이터 행:1100, 열:42
#   TEST_SEX  ITEM_F001  ITEM_F002  ...  ITEM_F039  ITEM_F040  ITEM_F041
# 0        M      167.6       72.8  ...        NaN      0.349        NaN
# 1        F      160.4       62.4  ...        NaN      0.436        NaN
# 2        M      181.1       84.4  ...        NaN      0.359        NaN
# 3        M      174.2       72.2  ...        NaN        NaN        NaN
# 4        M      169.4       80.2  ...        NaN      0.300        NaN
#
# [5 rows x 42 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TEST_SEX   1100 non-null   object
#  1   ITEM_F001  1100 non-null   float64
#  2   ITEM_F002  1100 non-null   float64
#  3   ITEM_F003  1072 non-null   float64
#  4   ITEM_F004  856 non-null    float64
#  5   ITEM_F005  1100 non-null   float64
#  6   ITEM_F006  1100 non-null   float64
#  7   ITEM_F007  1100 non-null   float64
#  8   ITEM_F008  1100 non-null   float64
#  9   ITEM_F009  45 non-null     float64
#  10  ITEM_F010  82 non-null     float64
#  11  ITEM_F011  0 non-null      float64
#  12  ITEM_F012  1099 non-null   float64
#  13  ITEM_F013  109 non-null    float64
#  14  ITEM_F014  109 non-null    float64
#  15  ITEM_F015  109 non-null    float64
#  16  ITEM_F016  109 non-null    float64
#  17  ITEM_F017  109 non-null    float64
#  18  ITEM_F018  1100 non-null   float64
#  19  ITEM_F019  973 non-null    float64
#  20  ITEM_F020  129 non-null    float64
#  21  ITEM_F021  106 non-null    float64
#  22  ITEM_F022  946 non-null    float64
#  23  ITEM_F023  0 non-null      float64
#  24  ITEM_F024  0 non-null      float64
#  25  ITEM_F025  0 non-null      float64
#  26  ITEM_F026  0 non-null      float64
#  27  ITEM_F027  0 non-null      float64
#  28  ITEM_F028  1100 non-null   float64
#  29  ITEM_F029  0 non-null      float64
#  30  ITEM_F030  115 non-null    float64
#  31  ITEM_F031  225 non-null    float64
#  32  ITEM_F032  224 non-null    float64
#  33  ITEM_F033  224 non-null    float64
#  34  ITEM_F034  114 non-null    float64
#  35  ITEM_F035  224 non-null    float64
#  36  ITEM_F036  744 non-null    float64
#  37  ITEM_F037  744 non-null    float64
#  38  ITEM_F038  0 non-null      float64
#  39  ITEM_F039  0 non-null      float64
#  40  ITEM_F040  857 non-null    float64
#  41  ITEM_F041  43 non-null     float64
# dtypes: float64(41), object(1)
# memory usage: 361.1+ KB

# %%
def columns_del(df):
  df = df.drop(['ITEM_F011','ITEM_F023','ITEM_F024','ITEM_F025','ITEM_F026','ITEM_F027','ITEM_F029','ITEM_F038','ITEM_F039'], axis=1)
  df.columns = ['성별', '키', '몸무게', '체지방율', '허리둘레','이완기혈압', '수축기혈압', '악력D', '악력ND', '윗몸말아올리기',
                '반복점프', '앉아윗몸앞으로궆히기', '일리노이', '체공시간', '협응력시간','협응력실수횟수', '협응력계산결과값', 'BMI', 
                '교차윗몸일으키기', '왕복오래달리기','10M4회왕복달리기', '제자리멀리뛰기', '상대악력', '왕복오래달리기', '트레드밀_안정시',
                '트레드밀_3분', '트레드밀_6분', '트레드밀_9분', '트레드밀_출력', '스텝검사_회복시심박수','스텝검사_출력', '전신반응', '체공시간2', 'AGE_GROUP', 'CERT_GBN']
  return df
df = columns_del(df)

# %%
def columns_del(df):
  df = df.drop(['ITEM_F011','ITEM_F023','ITEM_F024','ITEM_F025','ITEM_F026','ITEM_F027','ITEM_F029','ITEM_F038','ITEM_F039'], axis=1)
  df.columns = ['성별', '키', '몸무게', '체지방율', '허리둘레','이완기혈압', '수축기혈압', '악력D', '악력ND', '윗몸말아올리기',
                '반복점프', '앉아윗몸앞으로궆히기', '일리노이', '체공시간', '협응력시간','협응력실수횟수', '협응력계산결과값', 'BMI', 
                '교차윗몸일으키기', '왕복오래달리기','10M4회왕복달리기', '제자리멀리뛰기', '상대악력', '왕복오래달리기', '트레드밀_안정시',
                '트레드밀_3분', '트레드밀_6분', '트레드밀_9분', '트레드밀_출력', '스텝검사_회복시심박수','스텝검사_출력', '전신반응', '체공시간2']
  return df
test_df = columns_del(test_df)

# %%
test_df.head()
# Out:
#   성별      키   몸무게  체지방율  허리둘레  ...  트레드밀_출력  스텝검사_회복시심박수  스텝검사_출력   전신반응  체공시간2
# 0  M  167.6  72.8  27.4  92.9  ...      NaN        112.0     42.3  0.349    NaN
# 1  F  160.4  62.4  32.7  74.0  ...      NaN         87.0     33.4  0.436    NaN
# 2  M  181.1  84.4  18.0  94.4  ...      NaN        114.0     42.7  0.359    NaN
# 3  M  174.2  72.2  27.3  93.0  ...     39.2          NaN      NaN    NaN    NaN
# 4  M  169.4  80.2  29.8  96.3  ...      NaN        148.0     38.2  0.300    NaN
#
# [5 rows x 33 columns]

# %%
df.head()
# Out:
#   성별      키   몸무게  체지방율  허리둘레  ...  스텝검사_출력   전신반응  체공시간2  AGE_GROUP  CERT_GBN
# 0  F  162.7  56.4  20.2   NaN  ...     40.0  0.372  0.539        40대       1등급
# 1  M  168.6  66.6  20.8   NaN  ...     41.8  0.423    NaN        50대       참가증
# 2  F  162.6  62.4  34.7  78.3  ...     32.8  0.375    NaN        10대       참가증
# 3  M  179.3  84.1  28.6   NaN  ...     39.6  0.359    NaN        30대       참가증
# 4  M  174.5  75.4  28.3   NaN  ...     37.5  0.346    NaN        50대       참가증
#
# [5 rows x 35 columns]

# %%
df.loc[(df.AGE_GROUP  == '10대','AGE_GROUP')] = 1
df.loc[(df.AGE_GROUP  == '20대','AGE_GROUP')] = 2
df.loc[(df.AGE_GROUP  == '30대','AGE_GROUP')] = 3
df.loc[(df.AGE_GROUP  == '40대','AGE_GROUP')] = 4
df.loc[(df.AGE_GROUP  == '50대','AGE_GROUP')] = 5

df.loc[(df.CERT_GBN  == '참가증','CERT_GBN')] = 1
df.loc[(df.CERT_GBN  == '3등급','CERT_GBN')] = 2
df.loc[(df.CERT_GBN  == '2등급','CERT_GBN')] = 3
df.loc[(df.CERT_GBN  == '1등급','CERT_GBN')] = 4

df.loc[(df.성별  == 'F','성별')] = 1
df.loc[(df.성별  == 'M','성별')] = 2

# %%
df.head()
# Out:
#   성별      키   몸무게  체지방율  허리둘레  ...  스텝검사_출력   전신반응  체공시간2  AGE_GROUP  CERT_GBN
# 0  1  162.7  56.4  20.2   NaN  ...     40.0  0.372  0.539          4         4
# 1  2  168.6  66.6  20.8   NaN  ...     41.8  0.423    NaN          5         1
# 2  1  162.6  62.4  34.7  78.3  ...     32.8  0.375    NaN          1         1
# 3  2  179.3  84.1  28.6   NaN  ...     39.6  0.359    NaN          3         1
# 4  2  174.5  75.4  28.3   NaN  ...     37.5  0.346    NaN          5         1
#
# [5 rows x 35 columns]

# %%
df[df['성별']==1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24076 entries, 0 to 66385
# Data columns (total 35 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           24076 non-null  object
#  1   키            24066 non-null  float64
#  2   몸무게          24066 non-null  float64
#  3   체지방율         21534 non-null  float64
#  4   허리둘레         13754 non-null  float64
#  5   이완기혈압        24067 non-null  float64
#  6   수축기혈압        24068 non-null  float64
#  7   악력D          24036 non-null  float64
#  8   악력ND         24032 non-null  float64
#  9   윗몸말아올리기      8172 non-null   float64
#  10  반복점프         6762 non-null   float64
#  11  앉아윗몸앞으로궆히기   24014 non-null  float64
#  12  일리노이         12450 non-null  float64
#  13  체공시간         10557 non-null  float64
#  14  협응력시간        12430 non-null  float64
#  15  협응력실수횟수      12429 non-null  float64
#  16  협응력계산결과값     12429 non-null  float64
#  17  BMI          24075 non-null  float64
#  18  교차윗몸일으키기     8136 non-null   float64
#  19  왕복오래달리기      5424 non-null   float64
#  20  10M4회왕복달리기   451 non-null    float64
#  21  제자리멀리뛰기      20128 non-null  float64
#  22  상대악력         24060 non-null  float64
#  23  왕복오래달리기      4504 non-null   float64
#  24  트레드밀_안정시     1483 non-null   float64
#  25  트레드밀_3분      1480 non-null   float64
#  26  트레드밀_6분      1474 non-null   float64
#  27  트레드밀_9분      10 non-null     float64
#  28  트레드밀_출력      1472 non-null   float64
#  29  스텝검사_회복시심박수  13227 non-null  float64
#  30  스텝검사_출력      13227 non-null  float64
#  31  전신반응         7500 non-null   float64
#  32  체공시간2        752 non-null    float64
#  33  AGE_GROUP    24076 non-null  object
#  34  CERT_GBN     24076 non-null  object
# dtypes: float64(32), object(3)
# memory usage: 6.6+ MB

# %%
df[df['성별']==2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42312 entries, 1 to 66387
# Data columns (total 35 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           42312 non-null  object
#  1   키            42300 non-null  float64
#  2   몸무게          42302 non-null  float64
#  3   체지방율         39230 non-null  float64
#  4   허리둘레         22008 non-null  float64
#  5   이완기혈압        42296 non-null  float64
#  6   수축기혈압        42295 non-null  float64
#  7   악력D          42193 non-null  float64
#  8   악력ND         42221 non-null  float64
#  9   윗몸말아올리기      12126 non-null  float64
#  10  반복점프         10292 non-null  float64
#  11  앉아윗몸앞으로궆히기   42144 non-null  float64
#  12  일리노이         17656 non-null  float64
#  13  체공시간         14797 non-null  float64
#  14  협응력시간        18007 non-null  float64
#  15  협응력실수횟수      18002 non-null  float64
#  16  협응력계산결과값     18002 non-null  float64
#  17  BMI          42310 non-null  float64
#  18  교차윗몸일으키기     19254 non-null  float64
#  19  왕복오래달리기      10880 non-null  float64
#  20  10M4회왕복달리기   1473 non-null   float64
#  21  제자리멀리뛰기      33518 non-null  float64
#  22  상대악력         42282 non-null  float64
#  23  왕복오래달리기      9715 non-null   float64
#  24  트레드밀_안정시     2826 non-null   float64
#  25  트레드밀_3분      2817 non-null   float64
#  26  트레드밀_6분      2816 non-null   float64
#  27  트레드밀_9분      1497 non-null   float64
#  28  트레드밀_출력      2815 non-null   float64
#  29  스텝검사_회복시심박수  24074 non-null  float64
#  30  스텝검사_출력      24074 non-null  float64
#  31  전신반응         17171 non-null  float64
#  32  체공시간2        1665 non-null   float64
#  33  AGE_GROUP    42312 non-null  object
#  34  CERT_GBN     42312 non-null  object
# dtypes: float64(32), object(3)
# memory usage: 11.6+ MB

# %%
df[df['AGE_GROUP']==1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45053 entries, 2 to 66381
# Data columns (total 35 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           45053 non-null  object
#  1   키            45043 non-null  float64
#  2   몸무게          45044 non-null  float64
#  3   체지방율         39455 non-null  float64
#  4   허리둘레         23402 non-null  float64
#  5   이완기혈압        45045 non-null  float64
#  6   수축기혈압        45046 non-null  float64
#  7   악력D          44937 non-null  float64
#  8   악력ND         44963 non-null  float64
#  9   윗몸말아올리기      20298 non-null  float64
#  10  반복점프         17054 non-null  float64
#  11  앉아윗몸앞으로궆히기   44912 non-null  float64
#  12  일리노이         30106 non-null  float64
#  13  체공시간         25354 non-null  float64
#  14  협응력시간        30437 non-null  float64
#  15  협응력실수횟수      30431 non-null  float64
#  16  협응력계산결과값     30431 non-null  float64
#  17  BMI          45050 non-null  float64
#  18  교차윗몸일으키기     6188 non-null   float64
#  19  왕복오래달리기      15268 non-null  float64
#  20  10M4회왕복달리기   728 non-null    float64
#  21  제자리멀리뛰기      34430 non-null  float64
#  22  상대악력         45030 non-null  float64
#  23  왕복오래달리기      13184 non-null  float64
#  24  트레드밀_안정시     2474 non-null   float64
#  25  트레드밀_3분      2470 non-null   float64
#  26  트레드밀_6분      2470 non-null   float64
#  27  트레드밀_9분      496 non-null    float64
#  28  트레드밀_출력      2468 non-null   float64
#  29  스텝검사_회복시심박수  18998 non-null  float64
#  30  스텝검사_출력      18998 non-null  float64
#  31  전신반응         5302 non-null   float64
#  32  체공시간2        439 non-null    float64
#  33  AGE_GROUP    45053 non-null  object
#  34  CERT_GBN     45053 non-null  object
# dtypes: float64(32), object(3)
# memory usage: 12.4+ MB

# %%
df[df['AGE_GROUP']==2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11310 entries, 5 to 66387
# Data columns (total 35 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           11310 non-null  object
#  1   키            11300 non-null  float64
#  2   몸무게          11301 non-null  float64
#  3   체지방율         11295 non-null  float64
#  4   허리둘레         7354 non-null   float64
#  5   이완기혈압        11296 non-null  float64
#  6   수축기혈압        11296 non-null  float64
#  7   악력D          11284 non-null  float64
#  8   악력ND         11285 non-null  float64
#  9   윗몸말아올리기      0 non-null      float64
#  10  반복점프         0 non-null      float64
#  11  앉아윗몸앞으로궆히기   11269 non-null  float64
#  12  일리노이         0 non-null      float64
#  13  체공시간         0 non-null      float64
#  14  협응력시간        0 non-null      float64
#  15  협응력실수횟수      0 non-null      float64
#  16  협응력계산결과값     0 non-null      float64
#  17  BMI          11310 non-null  float64
#  18  교차윗몸일으키기     11262 non-null  float64
#  19  왕복오래달리기      879 non-null    float64
#  20  10M4회왕복달리기   824 non-null    float64
#  21  제자리멀리뛰기      10279 non-null  float64
#  22  상대악력         11294 non-null  float64
#  23  왕복오래달리기      878 non-null    float64
#  24  트레드밀_안정시     1026 non-null   float64
#  25  트레드밀_3분      1022 non-null   float64
#  26  트레드밀_6분      1023 non-null   float64
#  27  트레드밀_9분      673 non-null    float64
#  28  트레드밀_출력      1022 non-null   float64
#  29  스텝검사_회복시심박수  9362 non-null   float64
#  30  스텝검사_출력      9362 non-null   float64
#  31  전신반응         10124 non-null  float64
#  32  체공시간2        973 non-null    float64
#  33  AGE_GROUP    11310 non-null  object
#  34  CERT_GBN     11310 non-null  object
# dtypes: float64(32), object(3)
# memory usage: 3.1+ MB

# %%
df[df['AGE_GROUP']==3].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4034 entries, 3 to 66355
# Data columns (total 35 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           4034 non-null   object
#  1   키            4034 non-null   float64
#  2   몸무게          4034 non-null   float64
#  3   체지방율         4030 non-null   float64
#  4   허리둘레         1919 non-null   float64
#  5   이완기혈압        4033 non-null   float64
#  6   수축기혈압        4032 non-null   float64
#  7   악력D          4026 non-null   float64
#  8   악력ND         4026 non-null   float64
#  9   윗몸말아올리기      0 non-null      float64
#  10  반복점프         0 non-null      float64
#  11  앉아윗몸앞으로궆히기   4014 non-null   float64
#  12  일리노이         0 non-null      float64
#  13  체공시간         0 non-null      float64
#  14  협응력시간        0 non-null      float64
#  15  협응력실수횟수      0 non-null      float64
#  16  협응력계산결과값     0 non-null      float64
#  17  BMI          4034 non-null   float64
#  18  교차윗몸일으키기     4001 non-null   float64
#  19  왕복오래달리기      76 non-null     float64
#  20  10M4회왕복달리기   164 non-null    float64
#  21  제자리멀리뛰기      3588 non-null   float64
#  22  상대악력         4031 non-null   float64
#  23  왕복오래달리기      76 non-null     float64
#  24  트레드밀_안정시     318 non-null    float64
#  25  트레드밀_3분      316 non-null    float64
#  26  트레드밀_6분      316 non-null    float64
#  27  트레드밀_9분      193 non-null    float64
#  28  트레드밀_출력      316 non-null    float64
#  29  스텝검사_회복시심박수  3608 non-null   float64
#  30  스텝검사_출력      3608 non-null   float64
#  31  전신반응         3693 non-null   float64
#  32  체공시간2        422 non-null    float64
#  33  AGE_GROUP    4034 non-null   object
#  34  CERT_GBN     4034 non-null   object
# dtypes: float64(32), object(3)
# memory usage: 1.1+ MB

# %%
df[df['AGE_GROUP']==4].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3233 entries, 0 to 66360
# Data columns (total 35 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           3233 non-null   object
#  1   키            3233 non-null   float64
#  2   몸무게          3233 non-null   float64
#  3   체지방율         3232 non-null   float64
#  4   허리둘레         1539 non-null   float64
#  5   이완기혈압        3233 non-null   float64
#  6   수축기혈압        3233 non-null   float64
#  7   악력D          3229 non-null   float64
#  8   악력ND         3228 non-null   float64
#  9   윗몸말아올리기      0 non-null      float64
#  10  반복점프         0 non-null      float64
#  11  앉아윗몸앞으로궆히기   3217 non-null   float64
#  12  일리노이         0 non-null      float64
#  13  체공시간         0 non-null      float64
#  14  협응력시간        0 non-null      float64
#  15  협응력실수횟수      0 non-null      float64
#  16  협응력계산결과값     0 non-null      float64
#  17  BMI          3233 non-null   float64
#  18  교차윗몸일으키기     3202 non-null   float64
#  19  왕복오래달리기      43 non-null     float64
#  20  10M4회왕복달리기   119 non-null    float64
#  21  제자리멀리뛰기      2893 non-null   float64
#  22  상대악력         3232 non-null   float64
#  23  왕복오래달리기      43 non-null     float64
#  24  트레드밀_안정시     205 non-null    float64
#  25  트레드밀_3분      204 non-null    float64
#  26  트레드밀_6분      199 non-null    float64
#  27  트레드밀_9분      70 non-null     float64
#  28  트레드밀_출력      199 non-null    float64
#  29  스텝검사_회복시심박수  2944 non-null   float64
#  30  스텝검사_출력      2944 non-null   float64
#  31  전신반응         2973 non-null   float64
#  32  체공시간2        308 non-null    float64
#  33  AGE_GROUP    3233 non-null   object
#  34  CERT_GBN     3233 non-null   object
# dtypes: float64(32), object(3)
# memory usage: 909.3+ KB

# %%
df[df['AGE_GROUP']==5].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2758 entries, 1 to 66385
# Data columns (total 35 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           2758 non-null   object
#  1   키            2756 non-null   float64
#  2   몸무게          2756 non-null   float64
#  3   체지방율         2752 non-null   float64
#  4   허리둘레         1548 non-null   float64
#  5   이완기혈압        2756 non-null   float64
#  6   수축기혈압        2756 non-null   float64
#  7   악력D          2753 non-null   float64
#  8   악력ND         2751 non-null   float64
#  9   윗몸말아올리기      0 non-null      float64
#  10  반복점프         0 non-null      float64
#  11  앉아윗몸앞으로궆히기   2746 non-null   float64
#  12  일리노이         0 non-null      float64
#  13  체공시간         0 non-null      float64
#  14  협응력시간        0 non-null      float64
#  15  협응력실수횟수      0 non-null      float64
#  16  협응력계산결과값     0 non-null      float64
#  17  BMI          2758 non-null   float64
#  18  교차윗몸일으키기     2737 non-null   float64
#  19  왕복오래달리기      38 non-null     float64
#  20  10M4회왕복달리기   89 non-null     float64
#  21  제자리멀리뛰기      2456 non-null   float64
#  22  상대악력         2755 non-null   float64
#  23  왕복오래달리기      38 non-null     float64
#  24  트레드밀_안정시     286 non-null    float64
#  25  트레드밀_3분      285 non-null    float64
#  26  트레드밀_6분      282 non-null    float64
#  27  트레드밀_9분      75 non-null     float64
#  28  트레드밀_출력      282 non-null    float64
#  29  스텝검사_회복시심박수  2389 non-null   float64
#  30  스텝검사_출력      2389 non-null   float64
#  31  전신반응         2579 non-null   float64
#  32  체공시간2        275 non-null    float64
#  33  AGE_GROUP    2758 non-null   object
#  34  CERT_GBN     2758 non-null   object
# dtypes: float64(32), object(3)
# memory usage: 775.7+ KB

# %%
df = df.drop(['윗몸말아올리기','반복점프','일리노이', '체공시간', '협응력시간','협응력실수횟수','협응력계산결과값'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66388 entries, 0 to 66387
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           66388 non-null  object
#  1   키            66366 non-null  float64
#  2   몸무게          66368 non-null  float64
#  3   체지방율         60764 non-null  float64
#  4   허리둘레         35762 non-null  float64
#  5   이완기혈압        66363 non-null  float64
#  6   수축기혈압        66363 non-null  float64
#  7   악력D          66229 non-null  float64
#  8   악력ND         66253 non-null  float64
#  9   앉아윗몸앞으로궆히기   66158 non-null  float64
#  10  BMI          66385 non-null  float64
#  11  교차윗몸일으키기     27390 non-null  float64
#  12  왕복오래달리기      16304 non-null  float64
#  13  10M4회왕복달리기   1924 non-null   float64
#  14  제자리멀리뛰기      53646 non-null  float64
#  15  상대악력         66342 non-null  float64
#  16  왕복오래달리기      14219 non-null  float64
#  17  트레드밀_안정시     4309 non-null   float64
#  18  트레드밀_3분      4297 non-null   float64
#  19  트레드밀_6분      4290 non-null   float64
#  20  트레드밀_9분      1507 non-null   float64
#  21  트레드밀_출력      4287 non-null   float64
#  22  스텝검사_회복시심박수  37301 non-null  float64
#  23  스텝검사_출력      37301 non-null  float64
#  24  전신반응         24671 non-null  float64
#  25  체공시간2        2417 non-null   float64
#  26  AGE_GROUP    66388 non-null  object
#  27  CERT_GBN     66388 non-null  object
# dtypes: float64(25), object(3)
# memory usage: 14.2+ MB

# %%
df[df['성별']==1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24076 entries, 0 to 66385
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           24076 non-null  object
#  1   키            24066 non-null  float64
#  2   몸무게          24066 non-null  float64
#  3   체지방율         21534 non-null  float64
#  4   허리둘레         13754 non-null  float64
#  5   이완기혈압        24067 non-null  float64
#  6   수축기혈압        24068 non-null  float64
#  7   악력D          24036 non-null  float64
#  8   악력ND         24032 non-null  float64
#  9   앉아윗몸앞으로궆히기   24014 non-null  float64
#  10  BMI          24075 non-null  float64
#  11  교차윗몸일으키기     8136 non-null   float64
#  12  왕복오래달리기      5424 non-null   float64
#  13  10M4회왕복달리기   451 non-null    float64
#  14  제자리멀리뛰기      20128 non-null  float64
#  15  상대악력         24060 non-null  float64
#  16  왕복오래달리기      4504 non-null   float64
#  17  트레드밀_안정시     1483 non-null   float64
#  18  트레드밀_3분      1480 non-null   float64
#  19  트레드밀_6분      1474 non-null   float64
#  20  트레드밀_9분      10 non-null     float64
#  21  트레드밀_출력      1472 non-null   float64
#  22  스텝검사_회복시심박수  13227 non-null  float64
#  23  스텝검사_출력      13227 non-null  float64
#  24  전신반응         7500 non-null   float64
#  25  체공시간2        752 non-null    float64
#  26  AGE_GROUP    24076 non-null  object
#  27  CERT_GBN     24076 non-null  object
# dtypes: float64(25), object(3)
# memory usage: 5.3+ MB

# %%
df[df['성별']==2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42312 entries, 1 to 66387
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           42312 non-null  object
#  1   키            42300 non-null  float64
#  2   몸무게          42302 non-null  float64
#  3   체지방율         39230 non-null  float64
#  4   허리둘레         22008 non-null  float64
#  5   이완기혈압        42296 non-null  float64
#  6   수축기혈압        42295 non-null  float64
#  7   악력D          42193 non-null  float64
#  8   악력ND         42221 non-null  float64
#  9   앉아윗몸앞으로궆히기   42144 non-null  float64
#  10  BMI          42310 non-null  float64
#  11  교차윗몸일으키기     19254 non-null  float64
#  12  왕복오래달리기      10880 non-null  float64
#  13  10M4회왕복달리기   1473 non-null   float64
#  14  제자리멀리뛰기      33518 non-null  float64
#  15  상대악력         42282 non-null  float64
#  16  왕복오래달리기      9715 non-null   float64
#  17  트레드밀_안정시     2826 non-null   float64
#  18  트레드밀_3분      2817 non-null   float64
#  19  트레드밀_6분      2816 non-null   float64
#  20  트레드밀_9분      1497 non-null   float64
#  21  트레드밀_출력      2815 non-null   float64
#  22  스텝검사_회복시심박수  24074 non-null  float64
#  23  스텝검사_출력      24074 non-null  float64
#  24  전신반응         17171 non-null  float64
#  25  체공시간2        1665 non-null   float64
#  26  AGE_GROUP    42312 non-null  object
#  27  CERT_GBN     42312 non-null  object
# dtypes: float64(25), object(3)
# memory usage: 9.4+ MB

# %%
df['성별']=pd.to_numeric(df['성별'])
df['AGE_GROUP']=pd.to_numeric(df['AGE_GROUP'])
df['CERT_GBN'] = pd.to_numeric(df['CERT_GBN'])

# %%
df.corr(method='spearman')
# Out:
#                    성별         키       몸무게  ...     체공시간2  AGE_GROUP  CERT_GBN
# 성별           1.000000  0.629145  0.462745  ...  0.693320   0.079446  0.020712
# 키            0.629145  1.000000  0.679230  ...  0.563116   0.188273  0.100669
# 몸무게          0.462745  0.679230  1.000000  ...  0.326251   0.256952 -0.092001
# 체지방율        -0.545780 -0.432007  0.165945  ... -0.629716  -0.013734 -0.364068
# 허리둘레         0.291006  0.424507  0.828206  ...  0.074113   0.288558 -0.158219
# 이완기혈압        0.116347  0.158256  0.248154  ...  0.040226   0.205046 -0.025893
# 수축기혈압        0.242302  0.305226  0.388735  ...  0.111577   0.288015  0.038197
# 악력D          0.649531  0.765581  0.673003  ...  0.652807   0.323852  0.235929
# 악력ND         0.648507  0.768679  0.672317  ...  0.664904   0.313169  0.237823
# 앉아윗몸앞으로궆히기  -0.260942 -0.084711 -0.067648  ... -0.023842   0.052441  0.457949
# BMI          0.219848  0.271989  0.875691  ...  0.038010   0.226879 -0.184888
# 교차윗몸일으키기     0.437564  0.364209  0.190653  ...  0.680086  -0.319024  0.446778
# 왕복오래달리기      0.446038  0.310067  0.009445  ...  0.528013   0.092387  0.522588
# 10M4회왕복달리기  -0.533961 -0.359757 -0.154516  ... -0.500000   0.175128 -0.156291
# 제자리멀리뛰기      0.656428  0.656335  0.375301  ...  0.478788   0.219777  0.339850
# 상대악력         0.498432  0.454485  0.063398  ...  0.660965   0.200671  0.418074
# 왕복오래달리기      0.380242  0.235144 -0.098093  ...  0.608323   0.059910  0.405289
# 트레드밀_안정시     0.030513 -0.018352 -0.114647  ... -0.092581  -0.377793 -0.070830
# 트레드밀_3분     -0.147298 -0.122925 -0.116316  ... -0.232728  -0.308527 -0.142622
# 트레드밀_6분     -0.212089 -0.104481  0.005537  ... -0.332256  -0.012468 -0.225343
# 트레드밀_9분      0.122385  0.062776  0.097658  ... -0.088580   0.097726 -0.306285
# 트레드밀_출력      0.619082  0.396306 -0.062278  ...  0.701507  -0.474956  0.250165
# 스텝검사_회복시심박수 -0.203096 -0.178598 -0.156179  ... -0.100050  -0.454662 -0.189362
# 스텝검사_출력      0.665235  0.417956 -0.034571  ...  0.640482  -0.279565  0.207749
# 전신반응        -0.328982 -0.238370 -0.103791  ... -0.498354   0.155468 -0.188653
# 체공시간2        0.693320  0.563116  0.326251  ...  1.000000  -0.341553  0.252696
# AGE_GROUP    0.079446  0.188273  0.256952  ... -0.341553   1.000000  0.131534
# CERT_GBN     0.020712  0.100669 -0.092001  ...  0.252696   0.131534  1.000000
#
# [28 rows x 28 columns]

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(df.corr(method='spearman'), annot=True)
plt.show()

# %%
keep_columns=[]
na_info=df.isna().sum()
na_info
# Out:
# 성별                 0
# 키                 22
# 몸무게               20
# 체지방율            5624
# 허리둘레           30626
# 이완기혈압             25
# 수축기혈압             25
# 악력D              159
# 악력ND             135
# 앉아윗몸앞으로궆히기       230
# BMI                3
# 교차윗몸일으키기       38998
# 왕복오래달리기        50084
# 10M4회왕복달리기     64464
# 제자리멀리뛰기        12742
# 상대악력              46
# 왕복오래달리기        52169
# 트레드밀_안정시       62079
# 트레드밀_3분        62091
# 트레드밀_6분        62098
# 트레드밀_9분        64881
# 트레드밀_출력        62101
# 스텝검사_회복시심박수    29087
# 스텝검사_출력        29087
# 전신반응           41717
# 체공시간2          63971
# AGE_GROUP          0
# CERT_GBN           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66388 entries, 0 to 66387
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           66388 non-null  int64
#  1   키            66366 non-null  float64
#  2   몸무게          66368 non-null  float64
#  3   체지방율         60764 non-null  float64
#  4   허리둘레         35762 non-null  float64
#  5   이완기혈압        66363 non-null  float64
#  6   수축기혈압        66363 non-null  float64
#  7   악력D          66229 non-null  float64
#  8   악력ND         66253 non-null  float64
#  9   앉아윗몸앞으로궆히기   66158 non-null  float64
#  10  BMI          66385 non-null  float64
#  11  교차윗몸일으키기     27390 non-null  float64
#  12  왕복오래달리기      16304 non-null  float64
#  13  10M4회왕복달리기   1924 non-null   float64
#  14  제자리멀리뛰기      53646 non-null  float64
#  15  상대악력         66342 non-null  float64
#  16  왕복오래달리기      14219 non-null  float64
#  17  트레드밀_안정시     4309 non-null   float64
#  18  트레드밀_3분      4297 non-null   float64
#  19  트레드밀_6분      4290 non-null   float64
#  20  트레드밀_9분      1507 non-null   float64
#  21  트레드밀_출력      4287 non-null   float64
#  22  스텝검사_회복시심박수  37301 non-null  float64
#  23  스텝검사_출력      37301 non-null  float64
#  24  전신반응         24671 non-null  float64
#  25  체공시간2        2417 non-null   float64
#  26  AGE_GROUP    66388 non-null  int64
#  27  CERT_GBN     66388 non-null  int64
# dtypes: float64(25), int64(3)
# memory usage: 14.2 MB

# %%
df[df['CERT_GBN']==1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42526 entries, 1 to 66386
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           42526 non-null  int64
#  1   키            42504 non-null  float64
#  2   몸무게          42506 non-null  float64
#  3   체지방율         37221 non-null  float64
#  4   허리둘레         22888 non-null  float64
#  5   이완기혈압        42502 non-null  float64
#  6   수축기혈압        42502 non-null  float64
#  7   악력D          42399 non-null  float64
#  8   악력ND         42405 non-null  float64
#  9   앉아윗몸앞으로궆히기   42304 non-null  float64
#  10  BMI          42523 non-null  float64
#  11  교차윗몸일으키기     14603 non-null  float64
#  12  왕복오래달리기      11084 non-null  float64
#  13  10M4회왕복달리기   942 non-null    float64
#  14  제자리멀리뛰기      35555 non-null  float64
#  15  상대악력         42480 non-null  float64
#  16  왕복오래달리기      9295 non-null   float64
#  17  트레드밀_안정시     2206 non-null   float64
#  18  트레드밀_3분      2197 non-null   float64
#  19  트레드밀_6분      2189 non-null   float64
#  20  트레드밀_9분      858 non-null    float64
#  21  트레드밀_출력      2187 non-null   float64
#  22  스텝검사_회복시심박수  20399 non-null  float64
#  23  스텝검사_출력      20399 non-null  float64
#  24  전신반응         13259 non-null  float64
#  25  체공시간2        1412 non-null   float64
#  26  AGE_GROUP    42526 non-null  int64
#  27  CERT_GBN     42526 non-null  int64
# dtypes: float64(25), int64(3)
# memory usage: 9.4 MB

# %%
df[df['CERT_GBN']==2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12106 entries, 5 to 66387
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           12106 non-null  int64
#  1   키            12106 non-null  float64
#  2   몸무게          12106 non-null  float64
#  3   체지방율         11908 non-null  float64
#  4   허리둘레         6528 non-null   float64
#  5   이완기혈압        12106 non-null  float64
#  6   수축기혈압        12106 non-null  float64
#  7   악력D          12093 non-null  float64
#  8   악력ND         12100 non-null  float64
#  9   앉아윗몸앞으로궆히기   12099 non-null  float64
#  10  BMI          12106 non-null  float64
#  11  교차윗몸일으키기     6244 non-null   float64
#  12  왕복오래달리기      2816 non-null   float64
#  13  10M4회왕복달리기   479 non-null    float64
#  14  제자리멀리뛰기      9467 non-null   float64
#  15  상대악력         12106 non-null  float64
#  16  왕복오래달리기      2628 non-null   float64
#  17  트레드밀_안정시     1006 non-null   float64
#  18  트레드밀_3분      1003 non-null   float64
#  19  트레드밀_6분      1004 non-null   float64
#  20  트레드밀_9분      343 non-null    float64
#  21  트레드밀_출력      1003 non-null   float64
#  22  스텝검사_회복시심박수  8470 non-null   float64
#  23  스텝검사_출력      8470 non-null   float64
#  24  전신반응         5588 non-null   float64
#  25  체공시간2        525 non-null    float64
#  26  AGE_GROUP    12106 non-null  int64
#  27  CERT_GBN     12106 non-null  int64
# dtypes: float64(25), int64(3)
# memory usage: 2.7 MB

# %%
df[df['CERT_GBN']==3].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8244 entries, 59 to 66384
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           8244 non-null   int64
#  1   키            8244 non-null   float64
#  2   몸무게          8244 non-null   float64
#  3   체지방율         8150 non-null   float64
#  4   허리둘레         4369 non-null   float64
#  5   이완기혈압        8244 non-null   float64
#  6   수축기혈압        8243 non-null   float64
#  7   악력D          8228 non-null   float64
#  8   악력ND         8237 non-null   float64
#  9   앉아윗몸앞으로궆히기   8243 non-null   float64
#  10  BMI          8244 non-null   float64
#  11  교차윗몸일으키기     4614 non-null   float64
#  12  왕복오래달리기      1530 non-null   float64
#  13  10M4회왕복달리기   328 non-null    float64
#  14  제자리멀리뛰기      6159 non-null   float64
#  15  상대악력         8244 non-null   float64
#  16  왕복오래달리기      1444 non-null   float64
#  17  트레드밀_안정시     774 non-null    float64
#  18  트레드밀_3분      774 non-null    float64
#  19  트레드밀_6분      774 non-null    float64
#  20  트레드밀_9분      237 non-null    float64
#  21  트레드밀_출력      774 non-null    float64
#  22  스텝검사_회복시심박수  6079 non-null   float64
#  23  스텝검사_출력      6079 non-null   float64
#  24  전신반응         4141 non-null   float64
#  25  체공시간2        358 non-null    float64
#  26  AGE_GROUP    8244 non-null   int64
#  27  CERT_GBN     8244 non-null   int64
# dtypes: float64(25), int64(3)
# memory usage: 1.8 MB

# %%
df[df['CERT_GBN']==4].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3512 entries, 0 to 66385
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           3512 non-null   int64
#  1   키            3512 non-null   float64
#  2   몸무게          3512 non-null   float64
#  3   체지방율         3485 non-null   float64
#  4   허리둘레         1977 non-null   float64
#  5   이완기혈압        3511 non-null   float64
#  6   수축기혈압        3512 non-null   float64
#  7   악력D          3509 non-null   float64
#  8   악력ND         3511 non-null   float64
#  9   앉아윗몸앞으로궆히기   3512 non-null   float64
#  10  BMI          3512 non-null   float64
#  11  교차윗몸일으키기     1929 non-null   float64
#  12  왕복오래달리기      874 non-null    float64
#  13  10M4회왕복달리기   175 non-null    float64
#  14  제자리멀리뛰기      2465 non-null   float64
#  15  상대악력         3512 non-null   float64
#  16  왕복오래달리기      852 non-null    float64
#  17  트레드밀_안정시     323 non-null    float64
#  18  트레드밀_3분      323 non-null    float64
#  19  트레드밀_6분      323 non-null    float64
#  20  트레드밀_9분      69 non-null     float64
#  21  트레드밀_출력      323 non-null    float64
#  22  스텝검사_회복시심박수  2353 non-null   float64
#  23  스텝검사_출력      2353 non-null   float64
#  24  전신반응         1683 non-null   float64
#  25  체공시간2        122 non-null    float64
#  26  AGE_GROUP    3512 non-null   int64
#  27  CERT_GBN     3512 non-null   int64
# dtypes: float64(25), int64(3)
# memory usage: 795.7 KB

# %%
df.head()
# Out:
#    성별      키   몸무게  체지방율  허리둘레  ...  스텝검사_출력   전신반응  체공시간2  AGE_GROUP  CERT_GBN
# 0   1  162.7  56.4  20.2   NaN  ...     40.0  0.372  0.539          4         4
# 1   2  168.6  66.6  20.8   NaN  ...     41.8  0.423    NaN          5         1
# 2   1  162.6  62.4  34.7  78.3  ...     32.8  0.375    NaN          1         1
# 3   2  179.3  84.1  28.6   NaN  ...     39.6  0.359    NaN          3         1
# 4   2  174.5  75.4  28.3   NaN  ...     37.5  0.346    NaN          5         1
#
# [5 rows x 28 columns]

# %%
keep_columns=[]
na_info=df.isna().sum()
for index,data in enumerate(na_info):
  if data< 0.3*len(df):    #베이스라인에서는 총 데이터 량의 30%가 NA값일 경우 평균으로 채우려고 합니다 
    keep_columns.append(na_info.index[index])

df_2=df[keep_columns]
MEAN_INFO=df_2.mean()
df_2=df_2.fillna(MEAN_INFO)
print(*keep_columns,sep="\n")
# Out:
# 성별
# 키
# 몸무게
# 체지방율
# 이완기혈압
# 수축기혈압
# 악력D
# 악력ND
# 앉아윗몸앞으로궆히기
# BMI
# 제자리멀리뛰기
# 상대악력
# AGE_GROUP
# CERT_GBN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66388 entries, 0 to 66387
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   성별           66388 non-null  int64
#  1   키            66366 non-null  float64
#  2   몸무게          66368 non-null  float64
#  3   체지방율         60764 non-null  float64
#  4   허리둘레         35762 non-null  float64
#  5   이완기혈압        66363 non-null  float64
#  6   수축기혈압        66363 non-null  float64
#  7   악력D          66229 non-null  float64
#  8   악력ND         66253 non-null  float64
#  9   앉아윗몸앞으로궆히기   66158 non-null  float64
#  10  BMI          66385 non-null  float64
#  11  교차윗몸일으키기     27390 non-null  float64
#  12  왕복오래달리기      16304 non-null  float64
#  13  10M4회왕복달리기   1924 non-null   float64
#  14  제자리멀리뛰기      53646 non-null  float64
#  15  상대악력         66342 non-null  float64
#  16  왕복오래달리기      14219 non-null  float64
#  17  트레드밀_안정시     4309 non-null   float64
#  18  트레드밀_3분      4297 non-null   float64
#  19  트레드밀_6분      4290 non-null   float64
#  20  트레드밀_9분      1507 non-null   float64
#  21  트레드밀_출력      4287 non-null   float64
#  22  스텝검사_회복시심박수  37301 non-null  float64
#  23  스텝검사_출력      37301 non-null  float64
#  24  전신반응         24671 non-null  float64
#  25  체공시간2        2417 non-null   float64
#  26  AGE_GROUP    66388 non-null  int64
#  27  CERT_GBN     66388 non-null  int64
# dtypes: float64(25), int64(3)
# memory usage: 14.2 MB

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66388 entries, 0 to 66387
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   성별          66388 non-null  int64
#  1   키           66388 non-null  float64
#  2   몸무게         66388 non-null  float64
#  3   체지방율        66388 non-null  float64
#  4   이완기혈압       66388 non-null  float64
#  5   수축기혈압       66388 non-null  float64
#  6   악력D         66388 non-null  float64
#  7   악력ND        66388 non-null  float64
#  8   앉아윗몸앞으로궆히기  66388 non-null  float64
#  9   BMI         66388 non-null  float64
#  10  제자리멀리뛰기     66388 non-null  float64
#  11  상대악력        66388 non-null  float64
#  12  AGE_GROUP   66388 non-null  int64
#  13  CERT_GBN    66388 non-null  int64
# dtypes: float64(11), int64(3)
# memory usage: 7.1 MB

# %%
def hist(x) :
  plt.hist(df_2[x])
  plt.xlabel(x)

# %%
def scatter(x) : 
    plt.plot(x,'AGE_GROUP', linestyle='none', marker='o', markersize=3, color='blue', data = df_2)
    plt.xlabel(x)

# %%
plt.subplot(221)
hist('키')

plt.subplot(222)
hist('몸무게')

plt.subplot(223)
hist('체지방율')

plt.subplot(224)
hist('이완기혈압')

plt.tight_layout()
plt.show()

# %%
plt.subplot(221)
scatter('키')

plt.subplot(222)
scatter('몸무게')

plt.subplot(223)
scatter('체지방율')

plt.subplot(224)
scatter('이완기혈압')

plt.tight_layout()
plt.show()

# %%
plt.subplot(221)
hist('수축기혈압')

plt.subplot(222)
hist('악력D')

plt.subplot(223)
hist('악력ND')

plt.subplot(224)
hist('앉아윗몸앞으로궆히기')

plt.tight_layout()
plt.show()

# %%
plt.subplot(221)
scatter('수축기혈압')

plt.subplot(222)
scatter('악력D')

plt.subplot(223)
scatter('악력ND')

plt.subplot(224)
scatter('앉아윗몸앞으로궆히기')

plt.tight_layout()
plt.show()

# %%
plt.subplot(221)
hist('BMI')

plt.subplot(222)
hist('상대악력')

plt.subplot(223)
hist('제자리멀리뛰기')
plt.tight_layout()
plt.show()

# %%
plt.subplot(221)
scatter('BMI')

plt.subplot(222)
scatter('상대악력')

plt.subplot(223)
scatter('제자리멀리뛰기')
plt.tight_layout()
plt.show()

# %%
df.describe()
# Out:
#                  성별             키  ...     AGE_GROUP      CERT_GBN
# count  66388.000000  66388.000000  ...  66388.000000  66388.000000
# mean       1.637344    167.140141  ...      1.604160      1.589414
# std        0.480770      9.595247  ...      1.073038      0.898767
# min        1.000000     51.900000  ...      1.000000      1.000000
# 25%        1.000000    160.400000  ...      1.000000      1.000000
# 50%        2.000000    168.000000  ...      1.000000      1.000000
# 75%        2.000000    174.300000  ...      2.000000      2.000000
# max        2.000000    201.200000  ...      5.000000      4.000000
#
# [8 rows x 14 columns]

# %%
df_2 = df_2[~(df_2['BMI']>60)]
df_2 = df_2[~(df_2['제자리멀리뛰기']>500)]
df_2 = df_2[~(df_2['상대악력']>600)]
df_2 = df_2[~(df_2['앉아윗몸앞으로궆히기']>30)]
df_2 = df_2[~(df_2['수축기혈압']>200)]
df_2 = df_2[~(df_2['악력D']>400)]
df_2 = df_2[~(df_2['악력ND']>100)]
df_2 = df_2[~(df_2['몸무게']<20)]
df_2 = df_2[~(df_2['이완기혈압']>2000)]
df_2 = df_2[~(df_2['체지방율']>70)]
df_2 = df_2[~(df_2['키']<100)]

# %%
df_2.describe()
# Out:
#                  성별             키  ...     AGE_GROUP      CERT_GBN
# count  65727.000000  65727.000000  ...  65727.000000  65727.000000
# mean       1.641076    167.171557  ...      1.607133      1.583870
# std        0.479689      9.573043  ...      1.075868      0.894109
# min        1.000000    112.900000  ...      1.000000      1.000000
# 25%        1.000000    160.500000  ...      1.000000      1.000000
# 50%        2.000000    168.000000  ...      1.000000      1.000000
# 75%        2.000000    174.300000  ...      2.000000      2.000000
# max        2.000000    201.200000  ...      5.000000      4.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# <hr style="height:3px;border:none;color:#5F71F7;background-color:#5F71F7;" />
#
# # 머신러닝 분류 진행

# %% [markdown]
# ## 🛠 Config
#
# 밑에 있는 **보기**에서 학습에 필요한 변수들을 `선택`하고 `입력`한다.
#
# ### 사용가능한 모델
# ```
#
# #Models
# "LogisticRegression"
# "LogisticRegressionCV"
# "PassiveAggressiveClassifier"
# "Perceptron"
# "RidgeClassifier"
# "SGDClassifier"
# "AdaBoostClassifier"
# "BaggingClassifier"
# "ExtraTreesClassifier"
# "GradientBoostingClassifier"
# "RandomForestClassifier"
#
#
# # Reduce_dimensionality
#     1. PCA
# # scaler
#     1. StandardScaler
#     2. MinMaxScaler
#     3. MaxAbsScaler
#     4. RobustScaler
# ```

# %% [markdown]
# <img src='https://iaml.it/blog/optimizing-sklearn-pipelines/images/pipeline-diagram.png' width=60%>

# %%
df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-68302b2f4bd0> in <module>()
# ----> 1 df2.head()
#
# NameError: name 'df2' is not defined

# %%
# Configuration
# 경로 설정
config = ConfigTree()

# Data PATH
config.DATAPATH.ROOT = ""
config.DATAPATH.TEST = os.path.join('final_test.csv')

# sys
config.SYSTEM.SAVE_DIR = os.path.join('submission') # 저장되는 위치

# -------------------------------
# 1. 본인의 팀 이름을 영어로 입력해주세요. 
# -------------------------------
config.SYSTEM.TEAM_NAME = 'JBIG' # 팀 이름


# -------------------------------
# 2. 사용한 모델 이름을 입력해주세요.(대소문자 지키기)
# -------------------------------
config.MODEL.NAME = "GradientBoostingClassifier" # 모델이름

# -------------------------------
# 3. 사용할 데이터를 선택하세요. (['train1','train2','train3',train4',train5']
# -------------------------------
config.DATAPATH.TRAIN = ['train']#,'train2','train3','train4','train5']

train_df=None
for i in config.DATAPATH.TRAIN:
  df=pd.read_csv(os.path.join(i+'.csv'))
  if train_df is None:
    train_df=df
  else: 
    train_df=train_df.append(df)

# -------------------------------
# 4. NULL/N/A 처리. (['train1','train2','train3',train4',train5']
# -------------------------------
keep_columns=[]
na_info=train_df.isna().sum()
for index,data in enumerate(na_info):
  if data< 0.3*len(df):    #베이스라인에서는 총 데이터 량의 30%가 NA값일 경우 평균으로 채우려고 합니다 
    keep_columns.append(na_info.index[index])

keep_columns.remove('AGE_GROUP')
keep_columns.remove('CERT_GBN')
MEAN_INFO=train_df.mean() 
train_df=train_df.fillna(MEAN_INFO)
#-------------------------

# %%
# --- 추가사항.. (원치 않는다면 주석처리하기)--- #

# -------------------------------
# 3. 차원축소 방법 과 스케일링 방법 선택하기 
# -------------------------------
config.PREPROCESS.reduce_dim=None
#config.PREPROCESS.reduce_dim = {'reduce_dim':'PCA'} # 차원축소 기법사용
#config.PREPROCESS.SCALER=None
config.PREPROCESS.SCALER = {'scaler':'StandardScaler'} # 스케일링 기법사용

# %%
train_df.loc[(train_df.AGE_GROUP  == 1,'AGE_GROUP')] = '10대'
train_df.loc[(train_df.AGE_GROUP  == 2,'AGE_GROUP')] = '20대'
train_df.loc[(train_df.AGE_GROUP  == 3,'AGE_GROUP')] = '30대'
train_df.loc[(train_df.AGE_GROUP  == 4,'AGE_GROUP')] = '40대'
train_df.loc[(train_df.AGE_GROUP  == 5,'AGE_GROUP')] = '50대'

train_df.loc[(train_df.CERT_GBN  == 1,'CERT_GBN')] = '참가증'
train_df.loc[(train_df.CERT_GBN  == 2,'CERT_GBN')] = '3등급'
train_df.loc[(train_df.CERT_GBN  == 3,'CERT_GBN')] = '2등급'
train_df.loc[(train_df.CERT_GBN  == 4,'CERT_GBN')] = '1등급'

train_df.loc[(train_df.성별  == 1,'성별')] = 'F'
train_df.loc[(train_df.성별  == 2,'성별')] = 'M'

# %%
X = train_df.drop(['AGE_GROUP', 'CERT_GBN'], axis=1) # 독립변수 
Y = train_df[['AGE_GROUP','CERT_GBN']]

# %%
try:
    if len(keep_columns)!=0:
        X = X.loc[:,keep_columns]
    print('[INFO] 성공적으로 변수가 선택되었습니다. ')
    #남녀 데이터-> [1,0]
    categorical_data=['성별']
    X = pd.get_dummies(X,columns =categorical_data , drop_first = True)
    
except:
    print('[INFO] 변수이름을 다시 확인해주세요.')
# Out:
# [INFO] 성공적으로 변수가 선택되었습니다.

# %%
from sklearn import preprocessing 
#해당 코드 (순서를) 변경하시면 submission 할때 문제가 생길수도 있습니다 
AGE_LABEL=preprocessing.LabelEncoder().fit(['10대','20대','30대','40대','50대']) #Class 를 숫자로 변환  
CERT_LABEL=preprocessing.LabelEncoder().fit(['1등급','2등급','3등급','참가증'])
## 데이터 레이블과 Feature 분할
Y1 = AGE_LABEL.transform(Y['AGE_GROUP'] )
Y2 = CERT_LABEL.transform(Y['CERT_GBN'] )

# %% [markdown]
# # 모델 학습과 평가

# %% [markdown]
# ## Train Valid 분할
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/bb/ML_dataset_training_validation_test_sets.png/330px-ML_dataset_training_validation_test_sets.png" alt="Drawing" height="200">

# %%
# -------------------------------
# 6. 나눌 비율을 설정해주세요. 
# -------------------------------
RATIO = 0.2


assert  0<RATIO<1, '비율의 범위를 확인하십시요. 0부터 1 사이의 실수여야됩니다.'

# -------------------------------
# 7. 나이예측
# -------------------------------

X_train, X_valid, y_train, y_valid = train_test_split(X, pd.DataFrame({'age':Y1,'cert':Y2}), test_size=RATIO)

#SMOTE를 사용하는 방법도 있습니다 SMOTE가 무엇인지 직접 한번 찾아보세요
from imblearn.over_sampling import SMOTE
#sm = SMOTE(ratio='auto', kind='regular')
#X_resampled_age, y_resampled_age = sm.fit_sample(X_train,y_train['age'])
#X_resampled_cert, y_resampled_cert = sm.fit_sample(X_train,y_train['cert'])                                                      
# 모델설정
pipe = HealthClass(config).build_pipline(reduce_dim_params=None,
                                            model_params=None)
# Out:
# [INFO] PIPELINE SETUP SUCCESS
# ========================================
# [INFO] Details ...
# scaler    : StandardScaler(copy=True, with_mean=True, with_std=True)
# model     : GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
# ========================================

# %%
#파이프라인 사용 안할시 해당 아래 코드 참고 
#from sklearn.linear_model import LogisticRegression
#model=LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, 
#                         solver='lbfgs',max_iter=100, multi_class='auto', verbose=0, 
#                         warm_start=False, n_jobs=None, l1_ratio=None)
#model.fit(X_train,y_train['age'])

# %%
# train data 를 사용하여 모델 학습하기 
model1 = pipe.fit(X_train, y_train['age'])
model2 = pipe.fit(X_train, y_train['cert'])
#SMOTE DATA 로 사용하여 학습하기
#model1 = pipe.fit(X_resampled_age, y_resampled_age)
#model2 = pipe.fit(X_resampled_cert, y_resampled_cert)

# %%
plot_result(y_valid['age'], pipe.predict(X_valid))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-460-9787daaab898> in <module>()
# ----> 1 plot_result(y_valid['age'], pipe.predict(X_valid))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     114
#     115         # lambda, but not partial, allows help() to work with update_wrapper
# --> 116         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     117         # update the docstring of the returned function
#     118         update_wrapper(out, self.fn)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/pipeline.py in predict(self, X, **predict_params)
#     417         Xt = X
#     418         for _, name, transform in self._iter(with_final=False):
# --> 419             Xt = transform.transform(Xt)
#     420         return self.steps[-1][-1].predict(Xt, **predict_params)
#     421
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#     788             Copy the input X or not.
#     789         """
# --> 790         check_is_fitted(self)
#     791
#     792         copy = copy if copy is not None else self.copy
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     965
#     966     if not attrs:
# --> 967         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     968
#     969
#
# NotFittedError: This StandardScaler instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
plot_result(y_valid['cert'], pipe.predict(X_valid))

# %% [markdown]
# <hr style="height:3px;border:none;color:#5F71F7;background-color:#5F71F7;" />
#
# ## 🛠 학습된 모델로 예측하기

# %%
test_df.head()

# %%
train_df.columns
# Out:
# Index(['성별', '키', '몸무게', '체지방율', '이완기혈압', '수축기혈압', '악력D', '악력ND', '앉아윗몸앞으로궆히기',
#        'BMI', '제자리멀리뛰기', '상대악력', 'AGE_GROUP', 'CERT_GBN'],
#       dtype='object')

# %%
test_df = test_df[['성별', '키', '몸무게', '체지방율', '이완기혈압', '수축기혈압', '악력D', '악력ND', '앉아윗몸앞으로궆히기',
       'BMI', '제자리멀리뛰기', '상대악력']]

# %%
test_df.to_csv('test_2.csv',index=False)

# %%
test.head()
# Out:
#   성별      키   몸무게  체지방율  이완기혈압  ...  악력ND  앉아윗몸앞으로궆히기   BMI  제자리멀리뛰기  상대악력
# 0  M  167.6  72.8  27.4   97.0  ...  35.9        -1.2  25.9    156.0  70.0
# 1  F  160.4  62.4  32.7   69.0  ...  28.9        19.5  24.3    148.0  46.3
# 2  M  181.1  84.4  18.0   65.0  ...  52.0         9.5  25.7    206.0  64.0
# 3  M  174.2  72.2  27.3   76.0  ...  50.2       -16.8  23.8    198.0  74.0
# 4  M  169.4  80.2  29.8   93.0  ...  46.6        14.6  27.9    215.0  58.1
#
# [5 rows x 12 columns]

# %%
# 예측할 테스트(Test) 데이터 셋 불러오기


test = pd.read_csv('test_2.csv')
test.head()
X_test = test.loc[:,keep_columns]
print('[INFO] 성공적으로 변수가 선택되었습니다. ')
#남녀 데이터-> [1,0]
categorical_data=['성별']
X_test = pd.get_dummies(X_test,columns =categorical_data , drop_first = True)

MEAN_INFO=X_test.mean()
X_test=X_test.fillna(MEAN_INFO)
# Out:
# [INFO] 성공적으로 변수가 선택되었습니다.

# %%
pred_y_1 = pipe.predict(X_test)
pred_y_2 = pipe.predict(X_test)

# %%
submmision(config, pred_y_1,pred_y_2 ,test.index)
# Out:
#       NAME  AGE_GROUP  CERT_GBN
# 0        1          3         3
# 1        2          1         1
# 2        3          2         2
# 3        4          3         3
# 4        5          3         3
# ...    ...        ...       ...
# 1095  1096          1         1
# 1096  1097          3         3
# 1097  1098          3         3
# 1098  1099          1         1
# 1099  1100          3         3
#
# [1100 rows x 3 columns]
# [INFO] DATE: 20211030_065811
# [INFO] 제출 파일 저장 완료: submission/JBIG_20211030_065811.csv

# %% [markdown]
# 캐글/데이터 링크: https://www.kaggle.com/t/f480b32d2b834986bb725ac491f78d9d
